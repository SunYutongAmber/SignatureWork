# %% [markdown]
# <a href="https://colab.research.google.com/github/SunYutongAmber/SignatureWork/blob/main/code/SW_Regression_Model_fixed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import ast
import numpy as np
import math
import time
from pandas.core.frame import DataFrame
import matplotlib.pyplot as plt 
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

# %%
df_cryp=pd.read_csv('https://raw.githubusercontent.com/SunYutongAmber/SunYutongAmber/main/data/tx_db.csv')
df_cryp.head()
# Out:
#    Unnamed: 0        date  from    to  eth_price  punk_id   type  gender  \
# 0           0  2017-06-23  1406  1218       0.03     6548  Human    Male
# 1           1  2017-07-03  1218  3828       0.49     6548  Human    Male
# 2           2  2017-06-23  1406  1218       0.04     5719  Human  Female
# 3           3  2019-03-20   920  1472       0.99     5719  Human  Female
# 4           4  2017-06-23  1406  2518       0.25     1841  Human  Female
#
#   skin_tone  attr_count                                         attributes  \
# 0    Albino           4  ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...
# 1    Albino           4  ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...
# 2    Medium           3      ['Welding Goggles', 'Dark Hair', 'Cigarette']
# 3    Medium           3      ['Welding Goggles', 'Dark Hair', 'Cigarette']
# 4      Dark           3  ['Black Lipstick', 'Green Eye Shadow', 'Mohawk...
#
#   skin_tone_color                                            img_url
# 0         #F2DC5D  https://www.larvalabs.com/cryptopunks/cryptopu...
# 1         #F2DC5D  https://www.larvalabs.com/cryptopunks/cryptopu...
# 2         #DB9065  https://www.larvalabs.com/cryptopunks/cryptopu...
# 3         #DB9065  https://www.larvalabs.com/cryptopunks/cryptopu...
# 4         #A4031F  https://www.larvalabs.com/cryptopunks/cryptopu...

# %% [markdown]
# # Rarity Calculation

# %% [markdown]
# ## Trait Rarity

# %%
df_cryp['attributes']
# Out:
# 0        ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...
# 1        ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...
# 2            ['Welding Goggles', 'Dark Hair', 'Cigarette']
# 3            ['Welding Goggles', 'Dark Hair', 'Cigarette']
# 4        ['Black Lipstick', 'Green Eye Shadow', 'Mohawk...
#                                ...
# 17821                   ['Blonde Short', 'Classic Shades']
# 17822                  ['Frown', 'Do-rag', 'Small Shades']
# 17823        ['Clown Eyes Blue', 'Shadow Beard', 'Mohawk']
# 17824            ['Messy Hair', 'Earring', 'Normal Beard']
# 17825    ['Pipe', 'Straight Hair Blonde', 'Purple Lipst...
# Name: attributes, Length: 17826, dtype: object

# %%
list_of_all_attributes=df_cryp['attributes'].map(ast.literal_eval).sum()
#list_of_attributes

# %%
#get the polishe list for all the attributes
list_of_attributes_remove_the_repeats=list(set(df_cryp['attributes'].map(ast.literal_eval).sum()))
list_of_attributes_remove_the_repeats = [x for x in list_of_attributes_remove_the_repeats if x != '']
list_of_attributes_remove_the_repeats
# Out:
# ['Blue Eye Shadow',
#  '3D Glasses',
#  'Smile',
#  'Pipe',
#  'Shaved Head',
#  'Top Hat',
#  'Black Lipstick',
#  'Pink With Hat',
#  'Stringy Hair',
#  'Eye Mask',
#  'Gold Chain',
#  'Pigtails',
#  'Beanie',
#  'Handlebars',
#  'Goat',
#  'Spots',
#  'Purple Lipstick',
#  'Crazy Hair',
#  'Earring',
#  'Dark Hair',
#  'Clown Hair Green',
#  'Blonde Short',
#  'Red Mohawk',
#  'Wild Hair',
#  'Mohawk Thin',
#  'Normal Beard Black',
#  'Horned Rim Glasses',
#  'Clown Eyes Blue',
#  'Nerd Glasses',
#  'Straight Hair',
#  'Regular Shades',
#  'Luxurious Beard',
#  'Tiara',
#  'Tassle Hat',
#  'Blonde Bob',
#  'Cigarette',
#  'Rosy Cheeks',
#  'Wild Blonde',
#  'Bandana',
#  'Shadow Beard',
#  'Hoodie',
#  'Vape',
#  'Mohawk Dark',
#  'Peak Spike',
#  'Green Eye Shadow',
#  'Muttonchops',
#  'Fedora',
#  'Police Cap',
#  'Chinstrap',
#  'Vampire Hair',
#  'Pilot Helmet',
#  'Clown Eyes Green',
#  'Big Beard',
#  'Big Shades',
#  'Mustache',
#  'Messy Hair',
#  'Silver Chain',
#  'Purple Eye Shadow',
#  'Wild White Hair',
#  'Frown',
#  'Normal Beard',
#  'Medical Mask',
#  'Frumpy Hair',
#  'Do-rag',
#  'Choker',
#  'Hot Lipstick',
#  'Half Shaved',
#  'Knitted Cap',
#  'Straight Hair Blonde',
#  'Cap Forward',
#  'Buck Teeth',
#  'Cowboy Hat',
#  'Clown Nose',
#  'Cap',
#  'Eye Patch',
#  'Front Beard Dark',
#  'Orange Side',
#  'Straight Hair Dark',
#  'Front Beard',
#  'VR',
#  'Mohawk',
#  'Classic Shades',
#  'Welding Goggles',
#  'Headband',
#  'Purple Hair',
#  'Small Shades',
#  'Mole']

# %%
number_of_cryptopunks=len(df_cryp)
number_of_cryptopunks
# Out:
# 17826

# %%
traits_number_count=[]
trait_rarity_score=[]
for x in list_of_attributes_remove_the_repeats:
  a=list_of_all_attributes.count(x)
  traits_number_count.append(a)
  trait_rarity_score.append(number_of_cryptopunks/a)
#traits_number_count
#trait_rarity_score

# %% [markdown]
# ## Normalization of Trait Rarity score

# %%
normalization_trait_rarity_score=100*(np.array(trait_rarity_score)-min(trait_rarity_score))/(max(trait_rarity_score)-min(trait_rarity_score))
normalization_trait_rarity_score
# Out:
# array([  7.77017274,  11.5134493 ,  10.28705249,   7.46015416,
#          4.53253951,  23.5752305 ,   2.71042675,  41.43866155,
#          2.55578385,   6.00888146,  18.3315318 ,  35.90482791,
#         53.77449905,   6.05713819,   4.84489765,  16.47198226,
#          3.09352813,   5.33864487,   0.        ,  12.47781885,
#         15.74085903,  21.88060375,  17.18734275,   4.31984827,
#          3.14982989,   7.94384679,   2.97432252,   4.40287747,
#          3.29348593,  14.56934156,   3.15391294,   9.83286672,
#         74.78609039,  16.32064933,  26.08525128,   1.47870572,
#         17.52459474,  44.35550983,   2.89757711,   3.30225786,
#         12.04065631,   8.69137588,   3.78824574,   6.1060782 ,
#          8.10420188,   5.15868862,   9.77509102,  12.1687652 ,
#          4.92872906,  10.16220442,  77.81175954,   4.71570703,
#         18.42558656,   3.70214824,   5.42770006,   3.82694478,
#         10.35054361,   7.39042005,  26.65044477,   6.6222511 ,
#          5.7219032 ,  14.69127816,   3.8549842 ,   4.66875749,
#        100.        ,   3.10945219,  19.31548925,   4.18068666,
#         18.42558656,   7.28798454,  41.43866155,  22.55727763,
#         10.16220442,   6.16823638,   3.64478479,   5.64579941,
#         50.89922866,  13.1921112 ,   5.15868862,   7.5850695 ,
#          3.61918511,   3.08561397,  48.3114853 ,   4.24600864,
#         12.29944484,   4.66875749,   1.93794814])

# %%
df_traits = {'Traits':list_of_attributes_remove_the_repeats,
             'Number_Count': traits_number_count,
             'Traits_Rarity_Score': trait_rarity_score,
             'Normalized_Traits_Rarity_Score': normalization_trait_rarity_score}
df_traits=DataFrame(df_traits)

# %% [markdown]
# # Cryptopunk Rarity Score

# %% [markdown]
# ## Rarest Trait Score Model

# %%
rarity_score1=[]

for i in range(len(df_cryp)):
  length=len(df_cryp['attributes'][i].replace("[","").replace("]","").replace("'","").split(', '))
  #print(length)
  #average_rarity=[]
  list_index=[]
  for x in df_cryp['attributes'][i].replace("[","").replace("]","").replace("'","").split(', '):
    #print(x)
    if x in list(df_traits['Traits']):
      #print(x)
      #a=df_traits[df_traits.Traits==x].index.tolist()
      a=list(df_traits['Traits']).index(x)
      list_index.append(a)
      #average_rarity.append(b)
      #print(average_rarity)

  b=[df_traits['Normalized_Traits_Rarity_Score'][j] for j in list_index]
  #print(b)
  #average_rarity.append(b)
  c=max(b,default = 0)
  #print(c)
  rarity_score1.append(c)

len(rarity_score1)
# Out:
# 17826

# %%
df_cryp['Rarity_Score_1_rarest'] = rarity_score1
df_cryp
# Out:
#        Unnamed: 0        date  from    to  eth_price  punk_id   type  gender  \
# 0               0  2017-06-23  1406  1218       0.03     6548  Human    Male
# 1               1  2017-07-03  1218  3828       0.49     6548  Human    Male
# 2               2  2017-06-23  1406  1218       0.04     5719  Human  Female
# 3               3  2019-03-20   920  1472       0.99     5719  Human  Female
# 4               4  2017-06-23  1406  2518       0.25     1841  Human  Female
# ...           ...         ...   ...   ...        ...      ...    ...     ...
# 17821       17821  2022-07-17  2292  2070      88.88     4656  Human  Female
# 17822       17822  2022-07-17  5922   916      88.00     4749  Human    Male
# 17823       17823  2022-07-18   107  1044      84.00     4569  Human    Male
# 17824       17824  2022-07-21   244   801      86.68     4755  Human    Male
# 17825       17825  2022-07-23    10  1618     110.00     9544  Human  Female
#
#       skin_tone  attr_count  \
# 0        Albino           4
# 1        Albino           4
# 2        Medium           3
# 3        Medium           3
# 4          Dark           3
# ...         ...         ...
# 17821    Medium           2
# 17822    Medium           3
# 17823     Light           3
# 17824      Dark           3
# 17825     Light           3
#
#                                               attributes skin_tone_color  \
# 0      ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...         #F2DC5D
# 1      ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...         #F2DC5D
# 2          ['Welding Goggles', 'Dark Hair', 'Cigarette']         #DB9065
# 3          ['Welding Goggles', 'Dark Hair', 'Cigarette']         #DB9065
# 4      ['Black Lipstick', 'Green Eye Shadow', 'Mohawk...         #A4031F
# ...                                                  ...             ...
# 17821                 ['Blonde Short', 'Classic Shades']         #DB9065
# 17822                ['Frown', 'Do-rag', 'Small Shades']         #DB9065
# 17823      ['Clown Eyes Blue', 'Shadow Beard', 'Mohawk']         #F2A359
# 17824          ['Messy Hair', 'Earring', 'Normal Beard']         #A4031F
# 17825  ['Pipe', 'Straight Hair Blonde', 'Purple Lipst...         #F2A359
#
#                                                  img_url  \
# 0      https://www.larvalabs.com/cryptopunks/cryptopu...
# 1      https://www.larvalabs.com/cryptopunks/cryptopu...
# 2      https://www.larvalabs.com/cryptopunks/cryptopu...
# 3      https://www.larvalabs.com/cryptopunks/cryptopu...
# 4      https://www.larvalabs.com/cryptopunks/cryptopu...
# ...                                                  ...
# 17821  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17822  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17823  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17824  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17825  https://www.larvalabs.com/cryptopunks/cryptopu...
#
#        Rarity_Score_1_rarest
# 0                   5.158689
# 1                   5.158689
# 2                  48.311485
# 3                  48.311485
# 4                   8.104202
# ...                      ...
# 17821              21.880604
# 17822               6.622251
# 17823               4.402877
# 17824               5.721903
# 17825              18.425587
#
# [17826 rows x 14 columns]

# %% [markdown]
# ## Average Trait Rarity Model

# %%
rarity_score2=[]

for i in range(len(df_cryp)):
  length=len(df_cryp['attributes'][i].replace("[","").replace("]","").replace("'","").split(', '))
  #print(length)
  #average_rarity=[]
  list_index=[]
  for x in df_cryp['attributes'][i].replace("[","").replace("]","").replace("'","").split(', '):
    #print(x)
    if x in list(df_traits['Traits']):
      #print(x)
      #a=df_traits[df_traits.Traits==x].index.tolist()
      a=list(df_traits['Traits']).index(x)
      list_index.append(a)
      #print(a)
      #print(list_index)
      #b=df_traits['Normalized_Traits_Rarity_Score'][a]
      #print(b)
      #average_rarity.append(b)
      #print(average_rarity)

  b=[df_traits['Normalized_Traits_Rarity_Score'][j] for j in list_index]
  #print(b)
  #average_rarity.append(b)
  c=sum(b)/length
  #print(len(c))
  rarity_score2.append(c)

len(rarity_score2)
# Out:
# 17826

# %%
df_cryp['Rarity_Score_2_Average'] = rarity_score2
df_cryp
# Out:
#        Unnamed: 0        date  from    to  eth_price  punk_id   type  gender  \
# 0               0  2017-06-23  1406  1218       0.03     6548  Human    Male
# 1               1  2017-07-03  1218  3828       0.49     6548  Human    Male
# 2               2  2017-06-23  1406  1218       0.04     5719  Human  Female
# 3               3  2019-03-20   920  1472       0.99     5719  Human  Female
# 4               4  2017-06-23  1406  2518       0.25     1841  Human  Female
# ...           ...         ...   ...   ...        ...      ...    ...     ...
# 17821       17821  2022-07-17  2292  2070      88.88     4656  Human  Female
# 17822       17822  2022-07-17  5922   916      88.00     4749  Human    Male
# 17823       17823  2022-07-18   107  1044      84.00     4569  Human    Male
# 17824       17824  2022-07-21   244   801      86.68     4755  Human    Male
# 17825       17825  2022-07-23    10  1618     110.00     9544  Human  Female
#
#       skin_tone  attr_count  \
# 0        Albino           4
# 1        Albino           4
# 2        Medium           3
# 3        Medium           3
# 4          Dark           3
# ...         ...         ...
# 17821    Medium           2
# 17822    Medium           3
# 17823     Light           3
# 17824      Dark           3
# 17825     Light           3
#
#                                               attributes skin_tone_color  \
# 0      ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...         #F2DC5D
# 1      ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...         #F2DC5D
# 2          ['Welding Goggles', 'Dark Hair', 'Cigarette']         #DB9065
# 3          ['Welding Goggles', 'Dark Hair', 'Cigarette']         #DB9065
# 4      ['Black Lipstick', 'Green Eye Shadow', 'Mohawk...         #A4031F
# ...                                                  ...             ...
# 17821                 ['Blonde Short', 'Classic Shades']         #DB9065
# 17822                ['Frown', 'Do-rag', 'Small Shades']         #DB9065
# 17823      ['Clown Eyes Blue', 'Shadow Beard', 'Mohawk']         #F2A359
# 17824          ['Messy Hair', 'Earring', 'Normal Beard']         #A4031F
# 17825  ['Pipe', 'Straight Hair Blonde', 'Purple Lipst...         #F2A359
#
#                                                  img_url  \
# 0      https://www.larvalabs.com/cryptopunks/cryptopu...
# 1      https://www.larvalabs.com/cryptopunks/cryptopu...
# 2      https://www.larvalabs.com/cryptopunks/cryptopu...
# 3      https://www.larvalabs.com/cryptopunks/cryptopu...
# 4      https://www.larvalabs.com/cryptopunks/cryptopu...
# ...                                                  ...
# 17821  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17822  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17823  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17824  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17825  https://www.larvalabs.com/cryptopunks/cryptopu...
#
#        Rarity_Score_1_rarest  Rarity_Score_2_Average
# 0                   5.158689                3.635788
# 1                   5.158689                3.635788
# 2                  48.311485               20.756003
# 3                  48.311485               20.756003
# 4                   8.104202                4.654820
# ...                      ...                     ...
# 17821              21.880604               12.483109
# 17822               6.622251                5.319922
# 17823               4.402877                3.774773
# 17824               5.721903                3.182949
# 17825              18.425587                9.659756
#
# [17826 rows x 15 columns]

# %% [markdown]
# ## Statistical Rarity Model

# %%
rarity_score3=[]

for i in range(len(df_cryp)):
  length=len(df_cryp['attributes'][i].replace("[","").replace("]","").replace("'","").split(', '))
  #print(length)
  #average_rarity=[]
  list_index=[]
  for x in df_cryp['attributes'][i].replace("[","").replace("]","").replace("'","").split(', '):
    #print(x)
    if x in list(df_traits['Traits']):
      #print(x)
      #a=df_traits[df_traits.Traits==x].index.tolist()
      a=list(df_traits['Traits']).index(x)
      list_index.append(a)
      #average_rarity.append(b)
      #print(average_rarity)

  b=[df_traits['Normalized_Traits_Rarity_Score'][j] for j in list_index]
  #print(b)
  c=math.prod(b)
  #print(c)
  rarity_score3.append(c)

len(rarity_score3)
# Out:
# 17826

# %%
df_cryp['Rarity_Score_3_multiple'] = rarity_score3
df_cryp
# Out:
#        Unnamed: 0        date  from    to  eth_price  punk_id   type  gender  \
# 0               0  2017-06-23  1406  1218       0.03     6548  Human    Male
# 1               1  2017-07-03  1218  3828       0.49     6548  Human    Male
# 2               2  2017-06-23  1406  1218       0.04     5719  Human  Female
# 3               3  2019-03-20   920  1472       0.99     5719  Human  Female
# 4               4  2017-06-23  1406  2518       0.25     1841  Human  Female
# ...           ...         ...   ...   ...        ...      ...    ...     ...
# 17821       17821  2022-07-17  2292  2070      88.88     4656  Human  Female
# 17822       17822  2022-07-17  5922   916      88.00     4749  Human    Male
# 17823       17823  2022-07-18   107  1044      84.00     4569  Human    Male
# 17824       17824  2022-07-21   244   801      86.68     4755  Human    Male
# 17825       17825  2022-07-23    10  1618     110.00     9544  Human  Female
#
#       skin_tone  attr_count  \
# 0        Albino           4
# 1        Albino           4
# 2        Medium           3
# 3        Medium           3
# 4          Dark           3
# ...         ...         ...
# 17821    Medium           2
# 17822    Medium           3
# 17823     Light           3
# 17824      Dark           3
# 17825     Light           3
#
#                                               attributes skin_tone_color  \
# 0      ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...         #F2DC5D
# 1      ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...         #F2DC5D
# 2          ['Welding Goggles', 'Dark Hair', 'Cigarette']         #DB9065
# 3          ['Welding Goggles', 'Dark Hair', 'Cigarette']         #DB9065
# 4      ['Black Lipstick', 'Green Eye Shadow', 'Mohawk...         #A4031F
# ...                                                  ...             ...
# 17821                 ['Blonde Short', 'Classic Shades']         #DB9065
# 17822                ['Frown', 'Do-rag', 'Small Shades']         #DB9065
# 17823      ['Clown Eyes Blue', 'Shadow Beard', 'Mohawk']         #F2A359
# 17824          ['Messy Hair', 'Earring', 'Normal Beard']         #A4031F
# 17825  ['Pipe', 'Straight Hair Blonde', 'Purple Lipst...         #F2A359
#
#                                                  img_url  \
# 0      https://www.larvalabs.com/cryptopunks/cryptopu...
# 1      https://www.larvalabs.com/cryptopunks/cryptopu...
# 2      https://www.larvalabs.com/cryptopunks/cryptopu...
# 3      https://www.larvalabs.com/cryptopunks/cryptopu...
# 4      https://www.larvalabs.com/cryptopunks/cryptopu...
# ...                                                  ...
# 17821  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17822  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17823  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17824  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17825  https://www.larvalabs.com/cryptopunks/cryptopu...
#
#        Rarity_Score_1_rarest  Rarity_Score_2_Average  Rarity_Score_3_multiple
# 0                   5.158689                3.635788                 0.000000
# 1                   5.158689                3.635788                 0.000000
# 2                  48.311485               20.756003               891.396281
# 3                  48.311485               20.756003               891.396281
# 4                   8.104202                4.654820                69.188677
# ...                      ...                     ...                      ...
# 17821              21.880604               12.483109                67.515097
# 17822               6.622251                5.319922               144.347171
# 17823               4.402877                3.774773                52.620913
# 17824               5.721903                3.182949                 0.000000
# 17825              18.425587                9.659756               425.229311
#
# [17826 rows x 16 columns]

# %%
df_cryp.to_csv("gas_rarity_usd.csv")
df_cryp
# Out:
#        Unnamed: 0        date  from    to  eth_price  punk_id   type  gender  \
# 0               0  2017-06-23  1406  1218       0.03     6548  Human    Male
# 1               1  2017-07-03  1218  3828       0.49     6548  Human    Male
# 2               2  2017-06-23  1406  1218       0.04     5719  Human  Female
# 3               3  2019-03-20   920  1472       0.99     5719  Human  Female
# 4               4  2017-06-23  1406  2518       0.25     1841  Human  Female
# ...           ...         ...   ...   ...        ...      ...    ...     ...
# 17821       17821  2022-07-17  2292  2070      88.88     4656  Human  Female
# 17822       17822  2022-07-17  5922   916      88.00     4749  Human    Male
# 17823       17823  2022-07-18   107  1044      84.00     4569  Human    Male
# 17824       17824  2022-07-21   244   801      86.68     4755  Human    Male
# 17825       17825  2022-07-23    10  1618     110.00     9544  Human  Female
#
#       skin_tone  attr_count  \
# 0        Albino           4
# 1        Albino           4
# 2        Medium           3
# 3        Medium           3
# 4          Dark           3
# ...         ...         ...
# 17821    Medium           2
# 17822    Medium           3
# 17823     Light           3
# 17824      Dark           3
# 17825     Light           3
#
#                                               attributes skin_tone_color  \
# 0      ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...         #F2DC5D
# 1      ['Front Beard', 'Earring', 'Do-rag', 'Clown Ey...         #F2DC5D
# 2          ['Welding Goggles', 'Dark Hair', 'Cigarette']         #DB9065
# 3          ['Welding Goggles', 'Dark Hair', 'Cigarette']         #DB9065
# 4      ['Black Lipstick', 'Green Eye Shadow', 'Mohawk...         #A4031F
# ...                                                  ...             ...
# 17821                 ['Blonde Short', 'Classic Shades']         #DB9065
# 17822                ['Frown', 'Do-rag', 'Small Shades']         #DB9065
# 17823      ['Clown Eyes Blue', 'Shadow Beard', 'Mohawk']         #F2A359
# 17824          ['Messy Hair', 'Earring', 'Normal Beard']         #A4031F
# 17825  ['Pipe', 'Straight Hair Blonde', 'Purple Lipst...         #F2A359
#
#                                                  img_url  \
# 0      https://www.larvalabs.com/cryptopunks/cryptopu...
# 1      https://www.larvalabs.com/cryptopunks/cryptopu...
# 2      https://www.larvalabs.com/cryptopunks/cryptopu...
# 3      https://www.larvalabs.com/cryptopunks/cryptopu...
# 4      https://www.larvalabs.com/cryptopunks/cryptopu...
# ...                                                  ...
# 17821  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17822  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17823  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17824  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17825  https://www.larvalabs.com/cryptopunks/cryptopu...
#
#        Rarity_Score_1_rarest  Rarity_Score_2_Average  Rarity_Score_3_multiple
# 0                   5.158689                3.635788                 0.000000
# 1                   5.158689                3.635788                 0.000000
# 2                  48.311485               20.756003               891.396281
# 3                  48.311485               20.756003               891.396281
# 4                   8.104202                4.654820                69.188677
# ...                      ...                     ...                      ...
# 17821              21.880604               12.483109                67.515097
# 17822               6.622251                5.319922               144.347171
# 17823               4.402877                3.774773                52.620913
# 17824               5.721903                3.182949                 0.000000
# 17825              18.425587                9.659756               425.229311
#
# [17826 rows x 16 columns]

# %% [markdown]
# # Merge with Gas fee and ETH/USD data

# %% [markdown]
# ## import data and pre-processing

# %%
df_gas=pd.read_csv('https://raw.githubusercontent.com/SunYutongAmber/SignatureWork/main/Data/AvgGasPrice.csv')
df_gas.head()
# Out:
#    Date(UTC)  UnixTimeStamp  Value (Wei)
# 0  7/30/2015     1438214400            0
# 1  7/31/2015     1438300800            0
# 2   8/1/2015     1438387200            0
# 3   8/2/2015     1438473600            0
# 4   8/3/2015     1438560000            0

# %%
df_gas_ETH = {'date':df_gas['UnixTimeStamp'],
              'gas_eth_price':df_gas['Value (Wei)']*0.0042}
df_gas_ETH=DataFrame(df_gas_ETH)
df_gas_ETH
# Out:
#             date  gas_eth_price
# 0     1438214400   0.000000e+00
# 1     1438300800   0.000000e+00
# 2     1438387200   0.000000e+00
# 3     1438473600   0.000000e+00
# 4     1438560000   0.000000e+00
# ...          ...            ...
# 2760  1676678400   1.286364e+08
# 2761  1676764800   1.246275e+08
# 2762  1676851200   1.561191e+08
# 2763  1676937600   1.568683e+08
# 2764  1677024000   1.716411e+08
#
# [2765 rows x 2 columns]

# %%
df_usd=pd.read_csv('https://raw.githubusercontent.com/SunYutongAmber/SignatureWork/main/Data/EtherPrice%3AUSD.csv')
df_usd.head()
# Out:
#    Date(UTC)  UnixTimeStamp  Value
# 0  7/30/2015     1438214400    0.0
# 1  7/31/2015     1438300800    0.0
# 2   8/1/2015     1438387200    0.0
# 3   8/2/2015     1438473600    0.0
# 4   8/3/2015     1438560000    0.0

# %%
df_ETH_usd = {'date':df_usd['UnixTimeStamp'],
              'eth_usd_price':df_usd['Value']}
df_ETH_usd=DataFrame(df_ETH_usd)
df_ETH_usd
# Out:
#             date  eth_usd_price
# 0     1438214400           0.00
# 1     1438300800           0.00
# 2     1438387200           0.00
# 3     1438473600           0.00
# 4     1438560000           0.00
# ...          ...            ...
# 2760  1676678400        1691.98
# 2761  1676764800        1681.25
# 2762  1676851200        1703.53
# 2763  1676937600        1659.64
# 2764  1677024000        1643.28
#
# [2765 rows x 2 columns]

# %% [markdown]
# ## change the date format

# %%
new_date=[]
for i in range(len(df_cryp)):
  #转换成时间数组
  timeArray = time.strptime(df_cryp['date'][i], "%Y-%m-%d")
  #转换成时间戳
  timestamp = time.mktime(timeArray)
  new_date.append(timestamp)
len(new_date)
# Out:
# 17826

# %%
df_cryp['timestamp']=new_date

# %%
#new_date1=[]
#for i in range(len(df_gas_ETH)):
  #转换成时间数组
#  timeArray = time.strptime(df_gas_ETH['date'][i], "%Y-%m-%d")
  #转换成时间戳
#  timestamp = time.mktime(timeArray)
#  new_date1.append(timestamp)
#len(new_date1)

# %%
#df_gas_ETH['timestamp']=new_date1

# %%
#new_date2=[]
#for i in range(len(df_ETH_usd)):
  #转换成时间数组
#  timeArray = time.strptime(df_ETH_usd['date'][i], "%Y-%m-%d")
  #转换成时间戳
#  timestamp = time.mktime(timeArray)
#  new_date2.append(timestamp)
#len(new_date2)

# %%
#df_ETH_usd['timestamp']=new_date2

# %% [markdown]
# ## merge the three data

# %%
df_cryp=df_cryp.merge(df_gas_ETH,left_on = 'timestamp', right_on='date',how = 'left')#左连接，左侧DataFrame取全部，右侧DataFrame取部分

# %%
df_cryp=df_cryp.merge(df_ETH_usd,left_on = 'timestamp', right_on='date',how = 'left')#左连接，左侧DataFrame取全部，右侧DataFrame取部分

# %%
df_cryp.to_csv('2017to2022_rarity_gas_usd_price.csv')

# %% [markdown]
# ## Stationary Test

# %%
df_cryp['price']=df_cryp['eth_price']*df_cryp['eth_usd_price']
df_cryp
# Out:
#        Unnamed: 0      date_x  from    to  eth_price  punk_id   type  gender  \
# 0               0  2017-06-23  1406  1218       0.03     6548  Human    Male
# 1               1  2017-07-03  1218  3828       0.49     6548  Human    Male
# 2               2  2017-06-23  1406  1218       0.04     5719  Human  Female
# 3               3  2019-03-20   920  1472       0.99     5719  Human  Female
# 4               4  2017-06-23  1406  2518       0.25     1841  Human  Female
# ...           ...         ...   ...   ...        ...      ...    ...     ...
# 17821       17821  2022-07-17  2292  2070      88.88     4656  Human  Female
# 17822       17822  2022-07-17  5922   916      88.00     4749  Human    Male
# 17823       17823  2022-07-18   107  1044      84.00     4569  Human    Male
# 17824       17824  2022-07-21   244   801      86.68     4755  Human    Male
# 17825       17825  2022-07-23    10  1618     110.00     9544  Human  Female
#
#       skin_tone  attr_count  ...  \
# 0        Albino           4  ...
# 1        Albino           4  ...
# 2        Medium           3  ...
# 3        Medium           3  ...
# 4          Dark           3  ...
# ...         ...         ...  ...
# 17821    Medium           2  ...
# 17822    Medium           3  ...
# 17823     Light           3  ...
# 17824      Dark           3  ...
# 17825     Light           3  ...
#
#                                                  img_url  \
# 0      https://www.larvalabs.com/cryptopunks/cryptopu...
# 1      https://www.larvalabs.com/cryptopunks/cryptopu...
# 2      https://www.larvalabs.com/cryptopunks/cryptopu...
# 3      https://www.larvalabs.com/cryptopunks/cryptopu...
# 4      https://www.larvalabs.com/cryptopunks/cryptopu...
# ...                                                  ...
# 17821  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17822  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17823  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17824  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17825  https://www.larvalabs.com/cryptopunks/cryptopu...
#
#       Rarity_Score_1_rarest Rarity_Score_2_Average  Rarity_Score_3_multiple  \
# 0                  5.158689               3.635788                 0.000000
# 1                  5.158689               3.635788                 0.000000
# 2                 48.311485              20.756003               891.396281
# 3                 48.311485              20.756003               891.396281
# 4                  8.104202               4.654820                69.188677
# ...                     ...                    ...                      ...
# 17821             21.880604              12.483109                67.515097
# 17822              6.622251               5.319922               144.347171
# 17823              4.402877               3.774773                52.620913
# 17824              5.721903               3.182949                 0.000000
# 17825             18.425587               9.659756               425.229311
#
#           timestamp      date_y  gas_eth_price        date  eth_usd_price  \
# 0      1.498176e+09  1498176000   1.720330e+08  1498176000         326.85
# 1      1.499040e+09  1499040000   1.180929e+08  1499040000         276.41
# 2      1.498176e+09  1498176000   1.720330e+08  1498176000         326.85
# 3      1.553040e+09  1553040000   5.115253e+07  1553040000         140.22
# 4      1.498176e+09  1498176000   1.720330e+08  1498176000         326.85
# ...             ...         ...            ...         ...            ...
# 17821  1.658016e+09  1658016000   1.046061e+08  1658016000        1337.97
# 17822  1.658016e+09  1658016000   1.046061e+08  1658016000        1337.97
# 17823  1.658102e+09  1658102400   1.475703e+08  1658102400        1583.55
# 17824  1.658362e+09  1658361600   1.027865e+08  1658361600        1575.68
# 17825  1.658534e+09  1658534400   6.633055e+07  1658534400        1549.19
#
#              price
# 0           9.8055
# 1         135.4409
# 2          13.0740
# 3         138.8178
# 4          81.7125
# ...            ...
# 17821  118918.7736
# 17822  117741.3600
# 17823  133018.2000
# 17824  136579.9424
# 17825  170410.9000
#
# [17826 rows x 22 columns]

# %% [markdown]
# ## Kwiatkowski-Phillips-Schmidt-Shin – KPSS test (trend stationary)：

# %%
from statsmodels.tsa.stattools import adfuller, kpss
df = df_cryp

# KPSS Test
result = kpss(df.price.values, regression='c')
print('\nKPSS Statistic: %f' % result[0])
print('p-value: %f' % result[1])
for key, value in result[3].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# KPSS Statistic: 13.332689
# p-value: 0.010000
# Critial Values:
#    10%, 0.347
# Critial Values:
#    5%, 0.463
# Critial Values:
#    2.5%, 0.574
# Critial Values:
#    1%, 0.739
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# ## Log_transform and normalization

# %%
df_cryp['Log_price']=np.log(df_cryp['price'])
df_cryp['Log_price']
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0         2.282943
# 1         4.908535
# 2         2.570626
# 3         4.933162
# 4         4.403207
#            ...
# 17821    11.686196
# 17822    11.676246
# 17823    11.798241
# 17824    11.824665
# 17825    12.045968
# Name: Log_price, Length: 17826, dtype: float64

# %% [markdown]
# ## correlation test

# %%
# import modules
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb

df=df_cryp[['gas_eth_price','eth_usd_price','Rarity_Score_1_rarest']]
# import file with data
# data = pd.read_csv("C:\\Users\\Vanshi\\Desktop\\bestsellers.csv")

# prints data that will be plotted
# columns shown here are selected by corr() since
# they are ideal for the plot
print(df.corr())

# plotting correlation heatmap
dataplot = sb.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# displaying heatmap
mp.show()
# Out:
#                        gas_eth_price  eth_usd_price  Rarity_Score_1_rarest
# gas_eth_price               1.000000       0.237472              -0.008450
# eth_usd_price               0.237472       1.000000              -0.031512
# Rarity_Score_1_rarest      -0.008450      -0.031512               1.000000

# %%
# import modules
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb

df=df_cryp[['gas_eth_price','eth_usd_price','Rarity_Score_2_Average']]
# import file with data
# data = pd.read_csv("C:\\Users\\Vanshi\\Desktop\\bestsellers.csv")

# prints data that will be plotted
# columns shown here are selected by corr() since
# they are ideal for the plot
print(df.corr())

# plotting correlation heatmap
dataplot = sb.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# displaying heatmap
mp.show()
# Out:
#                         gas_eth_price  eth_usd_price  Rarity_Score_2_Average
# gas_eth_price                1.000000       0.237472               -0.017729
# eth_usd_price                0.237472       1.000000               -0.037558
# Rarity_Score_2_Average      -0.017729      -0.037558                1.000000

# %%
# import modules
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb

df=df_cryp[['gas_eth_price','eth_usd_price','Rarity_Score_3_multiple']]
# import file with data
# data = pd.read_csv("C:\\Users\\Vanshi\\Desktop\\bestsellers.csv")

# prints data that will be plotted
# columns shown here are selected by corr() since
# they are ideal for the plot
print(df.corr())

# plotting correlation heatmap
dataplot = sb.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# displaying heatmap
mp.show()
# Out:
#                          gas_eth_price  eth_usd_price  Rarity_Score_3_multiple
# gas_eth_price                 1.000000       0.237472                -0.003829
# eth_usd_price                 0.237472       1.000000                -0.008692
# Rarity_Score_3_multiple      -0.003829      -0.008692                 1.000000

# %% [markdown]
# ## normalization

# %%
df_cryp
# Out:
#        Unnamed: 0      date_x  from    to  eth_price  punk_id   type  gender  \
# 0               0  2017-06-23  1406  1218       0.03     6548  Human    Male
# 1               1  2017-07-03  1218  3828       0.49     6548  Human    Male
# 2               2  2017-06-23  1406  1218       0.04     5719  Human  Female
# 3               3  2019-03-20   920  1472       0.99     5719  Human  Female
# 4               4  2017-06-23  1406  2518       0.25     1841  Human  Female
# ...           ...         ...   ...   ...        ...      ...    ...     ...
# 17821       17821  2022-07-17  2292  2070      88.88     4656  Human  Female
# 17822       17822  2022-07-17  5922   916      88.00     4749  Human    Male
# 17823       17823  2022-07-18   107  1044      84.00     4569  Human    Male
# 17824       17824  2022-07-21   244   801      86.68     4755  Human    Male
# 17825       17825  2022-07-23    10  1618     110.00     9544  Human  Female
#
#       skin_tone  attr_count  ... Rarity_Score_1_rarest Rarity_Score_2_Average  \
# 0        Albino           4  ...              5.158689               3.635788
# 1        Albino           4  ...              5.158689               3.635788
# 2        Medium           3  ...             48.311485              20.756003
# 3        Medium           3  ...             48.311485              20.756003
# 4          Dark           3  ...              8.104202               4.654820
# ...         ...         ...  ...                   ...                    ...
# 17821    Medium           2  ...             21.880604              12.483109
# 17822    Medium           3  ...              6.622251               5.319922
# 17823     Light           3  ...              4.402877               3.774773
# 17824      Dark           3  ...              5.721903               3.182949
# 17825     Light           3  ...             18.425587               9.659756
#
#       Rarity_Score_3_multiple     timestamp      date_y  gas_eth_price  \
# 0                    0.000000  1.498176e+09  1498176000   1.720330e+08
# 1                    0.000000  1.499040e+09  1499040000   1.180929e+08
# 2                  891.396281  1.498176e+09  1498176000   1.720330e+08
# 3                  891.396281  1.553040e+09  1553040000   5.115253e+07
# 4                   69.188677  1.498176e+09  1498176000   1.720330e+08
# ...                       ...           ...         ...            ...
# 17821               67.515097  1.658016e+09  1658016000   1.046061e+08
# 17822              144.347171  1.658016e+09  1658016000   1.046061e+08
# 17823               52.620913  1.658102e+09  1658102400   1.475703e+08
# 17824                0.000000  1.658362e+09  1658361600   1.027865e+08
# 17825              425.229311  1.658534e+09  1658534400   6.633055e+07
#
#              date  eth_usd_price        price  Log_price
# 0      1498176000         326.85       9.8055   2.282943
# 1      1499040000         276.41     135.4409   4.908535
# 2      1498176000         326.85      13.0740   2.570626
# 3      1553040000         140.22     138.8178   4.933162
# 4      1498176000         326.85      81.7125   4.403207
# ...           ...            ...          ...        ...
# 17821  1658016000        1337.97  118918.7736  11.686196
# 17822  1658016000        1337.97  117741.3600  11.676246
# 17823  1658102400        1583.55  133018.2000  11.798241
# 17824  1658361600        1575.68  136579.9424  11.824665
# 17825  1658534400        1549.19  170410.9000  12.045968
#
# [17826 rows x 23 columns]

# %%
df_cryp['eth_usd_price']=np.log(df_cryp['eth_usd_price'])
df_cryp['gas_eth_price']=np.log(df_cryp['gas_eth_price'])
df_cryp['Rarity_Score_1_rarest']=np.log(df_cryp['Rarity_Score_1_rarest'])
df_cryp['Rarity_Score_2_Average']=np.log(df_cryp['Rarity_Score_2_Average'])
df_cryp['Rarity_Score_3_multiple']=np.log(df_cryp['Rarity_Score_3_multiple'])
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# # Hedonic Pricing Model for Rarity, Gas Fee and ETH/USD (Prediction)

# %% [markdown]
# multiple regression: https://blog.csdn.net/HHTNAN/article/details/78843722

# %% [markdown]
# ## sort the data with timestamp and then split training and testing set

# %%
df_cryp.sort_values('timestamp',inplace=True)
df_cryp=df_cryp.dropna()
df_cryp
# Out:
#        Unnamed: 0      date_x  from    to  eth_price  punk_id   type  gender  \
# 0               0  2017-06-23  1406  1218      0.030     6548  Human    Male
# 30             30  2017-06-23  1406  1218      0.116     8781  Human    Male
# 29             29  2017-06-23  1406   166      0.010     3134  Human    Male
# 28             28  2017-06-23   166  4722      0.100     5056  Human    Male
# 26             26  2017-06-23  1406  1218      0.060     6208  Human    Male
# ...           ...         ...   ...   ...        ...      ...    ...     ...
# 12450       12450  2022-07-26   980  1939     94.000     9099  Human    Male
# 17440       17440  2022-07-26  5318  4950     69.000     4430  Human  Female
# 17613       17613  2022-07-26  3002  1044     94.900     5600  Human    Male
# 13214       13214  2022-07-27  3096  1028     69.690     6221  Human  Female
# 17559       17559  2022-07-27   402  1955    104.950     2567  Human    Male
#
#       skin_tone  attr_count  ... Rarity_Score_1_rarest Rarity_Score_2_Average  \
# 0        Albino           4  ...              1.640682               1.290826
# 30        Light           4  ...              1.890435               1.493317
# 29       Medium           3  ...              2.908623               2.190688
# 28       Albino           4  ...              3.984799               2.879092
# 26       Medium           2  ...              1.194606               0.501459
# ...         ...         ...  ...                   ...                    ...
# 12450     Light           4  ...              1.691515               1.118827
# 17440    Albino           2  ...              1.550899               1.455201
# 17613    Albino           3  ...              2.908623               2.191850
# 13214      Dark           4  ...              2.960907               1.977492
# 17559     Light           3  ...              2.279837               1.715688
#
#       Rarity_Score_3_multiple     timestamp      date_y  gas_eth_price  \
# 0                        -inf  1.498176e+09  1498176000      18.963197
# 30                   5.824431  1.498176e+09  1498176000      18.963197
# 29                   5.732238  1.498176e+09  1498176000      18.963197
# 28                       -inf  1.498176e+09  1498176000      18.963197
# 26                       -inf  1.498176e+09  1498176000      18.963197
# ...                       ...           ...         ...            ...
# 12450                    -inf  1.658794e+09  1658793600      18.570040
# 17440                2.900266  1.658794e+09  1658793600      18.570040
# 17613                5.798883  1.658794e+09  1658793600      18.570040
# 13214                    -inf  1.658880e+09  1658880000      18.410773
# 17559                4.362520  1.658880e+09  1658880000      18.410773
#
#              date  eth_usd_price        price  Log_price
# 0      1498176000       5.789501       9.8055   2.282943
# 30     1498176000       5.789501      37.9146   3.635336
# 29     1498176000       5.789501       3.2685   1.184331
# 28     1498176000       5.789501      32.6850   3.486916
# 26     1498176000       5.789501      19.6110   2.976091
# ...           ...            ...          ...        ...
# 12450  1658793600       7.279050  136263.3400  11.822345
# 17440  1658793600       7.279050  100023.0900  11.513156
# 17613  1658793600       7.279050  137567.9890  11.831874
# 13214  1658880000       7.400547  114074.1672  11.644604
# 17559  1658880000       7.400547  171790.5560  12.054031
#
# [17826 rows x 23 columns]

# %%
df_cryp=df_cryp[df_cryp['Log_price']<10000]
df_cryp=df_cryp[df_cryp['Log_price']>-10000]
df_cryp=df_cryp[df_cryp['Rarity_Score_1_rarest']<10000]
df_cryp=df_cryp[df_cryp['Rarity_Score_1_rarest']>-10000]
df_cryp=df_cryp[df_cryp['Rarity_Score_2_Average']<10000]
df_cryp=df_cryp[df_cryp['Rarity_Score_2_Average']>-10000]
df_cryp=df_cryp[df_cryp['Rarity_Score_3_multiple']<10000]
df_cryp=df_cryp[df_cryp['Rarity_Score_3_multiple']>-10000]
df_cryp=df_cryp[df_cryp['gas_eth_price']<10000]
df_cryp=df_cryp[df_cryp['gas_eth_price']>-10000]
df_cryp=df_cryp[df_cryp['eth_usd_price']<10000]
df_cryp=df_cryp[df_cryp['eth_usd_price']>-10000]
len(df_cryp)
# Out:
# 12806

# %%
#df_cryp['eth_usd_price']=df_cryp['eth_usd_price'].apply(lambda x: float(x.replace(',','')))

# %% [markdown]
# Time Series data train and test split: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html

# %%
from sklearn.model_selection import TimeSeriesSplit
tss = TimeSeriesSplit()
print(tss)
# Out:
# TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None)

# %%
# change the train and test split parameters 
tss = TimeSeriesSplit(gap=0, max_train_size=None, n_splits=2, test_size=None)

# %%
for train_idx, test_idx in tss.split(df_cryp):
    print("TRAIN:", train_idx, "TEST:", test_idx)
# Out:
# TRAIN: [   0    1    2 ... 4267 4268 4269] TEST: [4270 4271 4272 ... 8535 8536 8537]
# TRAIN: [   0    1    2 ... 8535 8536 8537] TEST: [ 8538  8539  8540 ... 12803 12804 12805]

# %%
train_df = df_cryp.filter(items=train_idx, axis=0)
test_df =  df_cryp.filter(items=test_idx, axis=0)

# %%
train_df.head()
test_df.head()
# Out:
#       Unnamed: 0      date_x  from    to  eth_price  punk_id   type gender  \
# 8544        8544  2020-09-14  5801  1892       2.00     9886  Human   Male
# 8545        8545  2020-09-14  1532  5687       1.99     2057  Human   Male
# 8546        8546  2020-09-14  1532  5687       1.99     5849  Human   Male
# 8547        8547  2020-09-14  1532  5261       1.99     7307  Human   Male
# 8548        8548  2020-10-06  2913  2496       4.95     7307  Human   Male
#
#      skin_tone  attr_count  ... Rarity_Score_1_rarest Rarity_Score_2_Average  \
# 8544      Dark           3  ...              1.730912               1.464599
# 8545     Light           2  ...              2.072398               1.813496
# 8546     Light           2  ...              1.463220               1.337906
# 8547     Light           3  ...              1.463220               1.261905
# 8548     Light           3  ...              1.463220               1.261905
#
#      Rarity_Score_3_multiple     timestamp      date_y  gas_eth_price  \
# 8544                4.303642  1.600042e+09  1600041600      20.546410
# 8545                3.535618  1.600042e+09  1600041600      20.546410
# 8546                2.657827  1.600042e+09  1600041600      20.546410
# 8547                3.747843  1.600042e+09  1600041600      20.546410
# 8548                3.747843  1.601942e+09  1601942400      19.944078
#
#             date  eth_usd_price      price  Log_price
# 8544  1600041600       5.932882   754.4800   6.626029
# 8545  1600041600       5.932882   750.7076   6.621016
# 8546  1600041600       5.932882   750.7076   6.621016
# 8547  1600041600       5.932882   750.7076   6.621016
# 8548  1601942400       5.831442  1687.2075   7.430830
#
# [5 rows x 23 columns]

# %% [markdown]
# ## define X_train, X_test, y_train, and y_test

# %%
cols_R = ['Log_price','Rarity_Score_1_rarest','Rarity_Score_2_Average','Rarity_Score_3_multiple','gas_eth_price','eth_usd_price']
cols_R
# Out:
# ['Log_price',
#  'Rarity_Score_1_rarest',
#  'Rarity_Score_2_Average',
#  'Rarity_Score_3_multiple',
#  'gas_eth_price',
#  'eth_usd_price']

# %%
df_R_train = train_df[cols_R]
df_R_test = test_df[cols_R]
df_R_test.head()
# Out:
#       Log_price  Rarity_Score_1_rarest  Rarity_Score_2_Average  \
# 8544   6.626029               1.730912                1.464599
# 8545   6.621016               2.072398                1.813496
# 8546   6.621016               1.463220                1.337906
# 8547   6.621016               1.463220                1.261905
# 8548   7.430830               1.463220                1.261905
#
#       Rarity_Score_3_multiple  gas_eth_price  eth_usd_price
# 8544                 4.303642      20.546410       5.932882
# 8545                 3.535618      20.546410       5.932882
# 8546                 2.657827      20.546410       5.932882
# 8547                 3.747843      20.546410       5.932882
# 8548                 3.747843      19.944078       5.831442

# %%
from sklearn.linear_model import LinearRegression 
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %% [markdown]
# ## Hedonic regression with Rarity Score 1

# %%
import pandas as pd
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

#x = [1, 3, 5, 6, 8, 3, 4, 5, 1, 3, 5, 6, 8, 3, 4, 5, 0, 1, 0, 1, 1, 4, 5, 7]
#y = [0, 1, 0, 1, 1, 4, 5, 7, 0, 1, 0, 1, 1, 4, 5, 7, 0, 1, 0, 1, 1, 4, 5, 7]
#d = { "x": pd.Series(x), "y": pd.Series(y)}
#df = pd.DataFrame(d)
#df['xsqr'] = df['x']**2  
mod = smf.ols('Log_price ~ Rarity_Score_1_rarest',data=df_R_train)
res = mod.fit()
print(res.summary())

mod2= smf.ols('Log_price ~ Rarity_Score_1_rarest+gas_eth_price',data=df_R_train)
res2 = mod2.fit()
print(res2.summary())

mod3= smf.ols('Log_price ~ Rarity_Score_1_rarest+gas_eth_price+eth_usd_price',data=df_R_train)
res3 = mod3.fit()
print(res3.summary())

mod4= smf.ols('Log_price ~ gas_eth_price+eth_usd_price',data=df_R_train)
res4 = mod4.fit()
print(res4.summary())

dfoutput = summary_col([res,res2,res3,res4],stars=True)
print(dfoutput)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.1963
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):              0.658
# Time:                        15:42:12   Log-Likelihood:                -16531.
# No. Observations:                6155   AIC:                         3.307e+04
# Df Residuals:                    6153   BIC:                         3.308e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 8.0282      0.157     51.206      0.000       7.721       8.336
# Rarity_Score_1_rarest    -0.0313      0.071     -0.443      0.658      -0.170       0.107
# ==============================================================================
# Omnibus:                     1670.603   Durbin-Watson:                   1.478
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22356.630
# Skew:                          -0.921   Prob(JB):                         0.00
# Kurtosis:                      12.153   Cond. No.                         9.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.398
# Method:                 Least Squares   F-statistic:                     2032.
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:42:12   Log-Likelihood:                -14970.
# No. Observations:                6155   AIC:                         2.995e+04
# Df Residuals:                    6152   BIC:                         2.997e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept               -37.9135      0.731    -51.875      0.000     -39.346     -36.481
# Rarity_Score_1_rarest     0.2373      0.055      4.312      0.000       0.129       0.345
# gas_eth_price             2.3733      0.037     63.749      0.000       2.300       2.446
# ==============================================================================
# Omnibus:                     3100.036   Durbin-Watson:                   1.470
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           158220.378
# Skew:                          -1.661   Prob(JB):                         0.00
# Kurtosis:                      27.615   Cond. No.                         402.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     7508.
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:42:12   Log-Likelihood:                -11793.
# No. Observations:                6155   AIC:                         2.359e+04
# Df Residuals:                    6151   BIC:                         2.362e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept               -14.9888      0.487    -30.751      0.000     -15.944     -14.033
# Rarity_Score_1_rarest     0.2887      0.033      8.788      0.000       0.224       0.353
# gas_eth_price             0.3141      0.030     10.617      0.000       0.256       0.372
# eth_usd_price             2.4869      0.024    105.436      0.000       2.441       2.533
# ==============================================================================
# Omnibus:                     9466.026   Durbin-Watson:                   1.660
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9937584.125
# Skew:                          -9.321   Prob(JB):                         0.00
# Kurtosis:                     198.964   Cond. No.                         475.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                 1.109e+04
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:42:12   Log-Likelihood:                -11832.
# No. Observations:                6155   AIC:                         2.367e+04
# Df Residuals:                    6152   BIC:                         2.369e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -14.1185      0.480    -29.401      0.000     -15.060     -13.177
# gas_eth_price     0.3017      0.030     10.147      0.000       0.243       0.360
# eth_usd_price     2.4838      0.024    104.671      0.000       2.437       2.530
# ==============================================================================
# Omnibus:                     9385.706   Durbin-Watson:                   1.651
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9590017.477
# Skew:                          -9.164   Prob(JB):                         0.00
# Kurtosis:                     195.505   Cond. No.                         463.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ===========================================================================
#                       Log_price I Log_price II Log_price III Log_price IIII
# ---------------------------------------------------------------------------
# Intercept             8.0282***   -37.9135***  -14.9888***   -14.1185***
#                       (0.1568)    (0.7309)     (0.4874)      (0.4802)
# R-squared             0.0000      0.3978       0.7855        0.7828
# R-squared Adj.        -0.0001     0.3976       0.7854        0.7827
# Rarity_Score_1_rarest -0.0313     0.2373***    0.2887***
#                       (0.0707)    (0.0550)     (0.0328)
# eth_usd_price                                  2.4869***     2.4838***
#                                                (0.0236)      (0.0237)
# gas_eth_price                     2.3733***    0.3141***     0.3017***
#                                   (0.0372)     (0.0296)      (0.0297)
# ===========================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
X_train = pd.DataFrame(df_R_train,columns=['Rarity_Score_1_rarest','gas_eth_price','eth_usd_price'])
y_train = pd.DataFrame(df_R_train['Log_price'])
X_test = pd.DataFrame(df_R_test,columns=['Rarity_Score_1_rarest','gas_eth_price','eth_usd_price'])
y_test = pd.DataFrame(df_R_test['Log_price'])

# %%
mdl = linear_model.LinearRegression().fit(X_train,y_train)
y_pred = pd.DataFrame(np.array(mdl.predict(X_test)).astype(float),columns=['y_pred'])

#prediction graph
fig, ax = plt.subplots()
y_test.hist(ax=ax, label='true', alpha=.75,bins=100)
y_pred.hist(ax=ax, label='pred', alpha=.75)
ax.legend()
fig.show()

#evaluate regression model performance：均方根误差(Root Mean Squared Error, RMSE)
y_pred=y_pred.values.tolist()
sum_mean=0
for i in range(len(y_pred)):
  sum_mean+=(y_pred[i]-y_test.values[i])**2
sum_erro=np.sqrt(sum_mean/len(y_pred))  #这个10是你测试级的数量
# calculate RMSE by hand
print ("RMSE by hand:",sum_erro)
#做ROC曲线
plt.figure()
plt.plot(range(len(y_pred)),y_pred,'b',label="predict",alpha=1)
#plt.plot(range(len(y_pred)),y_test,'r',label="test",alpha=0.3)
plt.legend(loc="upper right") #显示图中的标签
#plt.xlabel("the number of sales")
plt.ylabel('value of cryptopunks')
plt.show()
# Out:
# RMSE by hand: [0.89536527]

# %% [markdown]
# ## Hedonic regression with Rarity Score 2

# %%
mod = smf.ols('Log_price ~ Rarity_Score_2_Average',data=df_R_train)
res = mod.fit()
print(res.summary())

mod2= smf.ols('Log_price ~ Rarity_Score_2_Average+gas_eth_price',data=df_R_train)
res2 = mod2.fit()
print(res2.summary())

mod3= smf.ols('Log_price ~ Rarity_Score_2_Average+gas_eth_price+eth_usd_price',data=df_R_train)
res3 = mod3.fit()
print(res3.summary())

mod4= smf.ols('Log_price ~ gas_eth_price+eth_usd_price',data=df_R_train)
res4 = mod4.fit()
print(res4.summary())

dfoutput = summary_col([res,res2,res3,res4],stars=True)
print(dfoutput)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.3526
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):              0.553
# Time:                        15:42:14   Log-Likelihood:                -16531.
# No. Observations:                6155   AIC:                         3.307e+04
# Df Residuals:                    6153   BIC:                         3.308e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  8.0556      0.164     48.987      0.000       7.733       8.378
# Rarity_Score_2_Average    -0.0532      0.090     -0.594      0.553      -0.229       0.122
# ==============================================================================
# Omnibus:                     1671.185   Durbin-Watson:                   1.478
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22378.106
# Skew:                          -0.921   Prob(JB):                         0.00
# Kurtosis:                      12.158   Cond. No.                         8.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.398
# Method:                 Least Squares   F-statistic:                     2034.
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:42:14   Log-Likelihood:                -14969.
# No. Observations:                6155   AIC:                         2.994e+04
# Df Residuals:                    6152   BIC:                         2.996e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                -37.9969      0.733    -51.813      0.000     -39.434     -36.559
# Rarity_Score_2_Average     0.3150      0.070      4.516      0.000       0.178       0.452
# gas_eth_price              2.3749      0.037     63.770      0.000       2.302       2.448
# ==============================================================================
# Omnibus:                     3100.359   Durbin-Watson:                   1.471
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           158177.367
# Skew:                          -1.661   Prob(JB):                         0.00
# Kurtosis:                      27.612   Cond. No.                         403.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                     7520.
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:42:14   Log-Likelihood:                -11790.
# No. Observations:                6155   AIC:                         2.359e+04
# Df Residuals:                    6151   BIC:                         2.361e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                -15.0865      0.488    -30.887      0.000     -16.044     -14.129
# Rarity_Score_2_Average     0.3828      0.042      9.199      0.000       0.301       0.464
# gas_eth_price              0.3158      0.030     10.680      0.000       0.258       0.374
# eth_usd_price              2.4872      0.024    105.509      0.000       2.441       2.533
# ==============================================================================
# Omnibus:                     9474.176   Durbin-Watson:                   1.660
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9969171.870
# Skew:                          -9.337   Prob(JB):                         0.00
# Kurtosis:                     199.275   Cond. No.                         475.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                 1.109e+04
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:42:14   Log-Likelihood:                -11832.
# No. Observations:                6155   AIC:                         2.367e+04
# Df Residuals:                    6152   BIC:                         2.369e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -14.1185      0.480    -29.401      0.000     -15.060     -13.177
# gas_eth_price     0.3017      0.030     10.147      0.000       0.243       0.360
# eth_usd_price     2.4838      0.024    104.671      0.000       2.437       2.530
# ==============================================================================
# Omnibus:                     9385.706   Durbin-Watson:                   1.651
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9590017.477
# Skew:                          -9.164   Prob(JB):                         0.00
# Kurtosis:                     195.505   Cond. No.                         463.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ============================================================================
#                        Log_price I Log_price II Log_price III Log_price IIII
# ----------------------------------------------------------------------------
# Intercept              8.0556***   -37.9969***  -15.0865***   -14.1185***
#                        (0.1644)    (0.7333)     (0.4884)      (0.4802)
# R-squared              0.0001      0.3980       0.7858        0.7828
# R-squared Adj.         -0.0001     0.3978       0.7856        0.7827
# Rarity_Score_2_Average -0.0532     0.3150***    0.3828***
#                        (0.0896)    (0.0697)     (0.0416)
# eth_usd_price                                   2.4872***     2.4838***
#                                                 (0.0236)      (0.0237)
# gas_eth_price                      2.3749***    0.3158***     0.3017***
#                                    (0.0372)     (0.0296)      (0.0297)
# ============================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
X_train = pd.DataFrame(df_R_train,columns=['Rarity_Score_2_Average','gas_eth_price','eth_usd_price'])
y_train = pd.DataFrame(df_R_train['Log_price'])
X_test = pd.DataFrame(df_R_test,columns=['Rarity_Score_2_Average','gas_eth_price','eth_usd_price'])
y_test = pd.DataFrame(df_R_test['Log_price'])

# %%
mdl = linear_model.LinearRegression().fit(X_train,y_train)
y_pred = pd.DataFrame(np.array(mdl.predict(X_test)).astype(float),columns=['y_pred'])

#prediction graph
fig, ax = plt.subplots()
y_test.hist(ax=ax, label='true', alpha=.75,bins=100)
y_pred.hist(ax=ax, label='pred', alpha=.75)
ax.legend()
fig.show()

#evaluate regression model performance：均方根误差(Root Mean Squared Error, RMSE)
y_pred=y_pred.values.tolist()
sum_mean=0
for i in range(len(y_pred)):
  sum_mean+=(y_pred[i]-y_test.values[i])**2
sum_erro=np.sqrt(sum_mean/len(y_pred))  #这个10是你测试级的数量
# calculate RMSE by hand
print ("RMSE by hand:",sum_erro)

#做ROC曲线
plt.figure()
plt.plot(range(len(y_pred)),y_pred,'b',label="predict",alpha=1)
#plt.plot(range(len(y_pred)),y_test,'r',label="test",alpha=0.3)
plt.legend(loc="upper right") #显示图中的标签
#plt.xlabel("the number of sales")
plt.ylabel('value of cryptopunks')
plt.show()
# Out:
# RMSE by hand: [0.89160571]

# %% [markdown]
# ## Hedonic regression with Rarity Score 3

# %%
mod = smf.ols('Log_price ~ Rarity_Score_3_multiple',data=df_R_train)
res = mod.fit()
print(res.summary())

mod2= smf.ols('Log_price ~ Rarity_Score_3_multiple+gas_eth_price',data=df_R_train)
res2 = mod2.fit()
print(res2.summary())

mod3= smf.ols('Log_price ~ Rarity_Score_3_multiple+gas_eth_price+eth_usd_price',data=df_R_train)
res3 = mod3.fit()
print(res3.summary())

mod4= smf.ols('Log_price ~ gas_eth_price+eth_usd_price',data=df_R_train)
res4 = mod4.fit()
print(res4.summary())

dfoutput = summary_col([res,res2,res3,res4],stars=True)
print(dfoutput)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     4.028
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):             0.0448
# Time:                        15:42:15   Log-Likelihood:                -16529.
# No. Observations:                6155   AIC:                         3.306e+04
# Df Residuals:                    6153   BIC:                         3.308e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   8.2436      0.148     55.858      0.000       7.954       8.533
# Rarity_Score_3_multiple    -0.0672      0.033     -2.007      0.045      -0.133      -0.002
# ==============================================================================
# Omnibus:                     1678.297   Durbin-Watson:                   1.480
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22552.799
# Skew:                          -0.926   Prob(JB):                         0.00
# Kurtosis:                      12.193   Cond. No.                         15.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.396
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     2020.
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:42:15   Log-Likelihood:                -14978.
# No. Observations:                6155   AIC:                         2.996e+04
# Df Residuals:                    6152   BIC:                         2.998e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                 -37.4731      0.729    -51.404      0.000     -38.902     -36.044
# Rarity_Score_3_multiple     0.0488      0.026      1.872      0.061      -0.002       0.100
# gas_eth_price               2.3658      0.037     63.503      0.000       2.293       2.439
# ==============================================================================
# Omnibus:                     3101.040   Durbin-Watson:                   1.468
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           157429.671
# Skew:                          -1.663   Prob(JB):                         0.00
# Kurtosis:                      27.552   Cond. No.                         407.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.784
# Method:                 Least Squares   F-statistic:                     7465.
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:42:15   Log-Likelihood:                -11807.
# No. Observations:                6155   AIC:                         2.362e+04
# Df Residuals:                    6151   BIC:                         2.365e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                 -14.7305      0.486    -30.297      0.000     -15.684     -13.777
# Rarity_Score_3_multiple     0.1094      0.016      7.021      0.000       0.079       0.140
# gas_eth_price               0.3076      0.030     10.381      0.000       0.249       0.366
# eth_usd_price               2.4900      0.024    105.268      0.000       2.444       2.536
# ==============================================================================
# Omnibus:                     9426.321   Durbin-Watson:                   1.657
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9794822.223
# Skew:                          -9.242   Prob(JB):                         0.00
# Kurtosis:                     197.553   Cond. No.                         480.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Log_price   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                 1.109e+04
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:42:15   Log-Likelihood:                -11832.
# No. Observations:                6155   AIC:                         2.367e+04
# Df Residuals:                    6152   BIC:                         2.369e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -14.1185      0.480    -29.401      0.000     -15.060     -13.177
# gas_eth_price     0.3017      0.030     10.147      0.000       0.243       0.360
# eth_usd_price     2.4838      0.024    104.671      0.000       2.437       2.530
# ==============================================================================
# Omnibus:                     9385.706   Durbin-Watson:                   1.651
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9590017.477
# Skew:                          -9.164   Prob(JB):                         0.00
# Kurtosis:                     195.505   Cond. No.                         463.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# =============================================================================
#                         Log_price I Log_price II Log_price III Log_price IIII
# -----------------------------------------------------------------------------
# Intercept               8.2436***   -37.4731***  -14.7305***   -14.1185***
#                         (0.1476)    (0.7290)     (0.4862)      (0.4802)
# R-squared               0.0007      0.3963       0.7845        0.7828
# R-squared Adj.          0.0005      0.3962       0.7844        0.7827
# Rarity_Score_3_multiple -0.0672**   0.0488*      0.1094***
#                         (0.0335)    (0.0261)     (0.0156)
# eth_usd_price                                    2.4900***     2.4838***
#                                                  (0.0237)      (0.0237)
# gas_eth_price                       2.3658***    0.3076***     0.3017***
#                                     (0.0373)     (0.0296)      (0.0297)
# =============================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
X_train = pd.DataFrame(df_R_train,columns=['Rarity_Score_3_multiple','gas_eth_price','eth_usd_price'])
y_train = pd.DataFrame(df_R_train['Log_price'])
X_test = pd.DataFrame(df_R_test,columns=['Rarity_Score_3_multiple','gas_eth_price','eth_usd_price'])
y_test = pd.DataFrame(df_R_test['Log_price'])

# %%
mdl = linear_model.LinearRegression().fit(X_train,y_train)
y_pred = pd.DataFrame(np.array(mdl.predict(X_test)).astype(float),columns=['y_pred'])

#prediction graph
fig, ax = plt.subplots()
y_test.hist(ax=ax, label='true', alpha=.75,bins=100)
y_pred.hist(ax=ax, label='pred', alpha=.75)
ax.legend()
fig.show()

#evaluate regression model performance：均方根误差(Root Mean Squared Error, RMSE)
y_pred=y_pred.values.tolist()
sum_mean=0
for i in range(len(y_pred)):
  sum_mean+=(y_pred[i]-y_test.values[i])**2
sum_erro=np.sqrt(sum_mean/len(y_pred))  #这个10是你测试级的数量
# calculate RMSE by hand
print ("RMSE by hand:",sum_erro)

#做ROC曲线
plt.figure()
plt.plot(range(len(y_pred)),y_pred,'b',label="predict",alpha=1)
#plt.plot(range(len(y_pred)),y_test,'r',label="test",alpha=0.3)
plt.legend(loc="upper right") #显示图中的标签
#plt.xlabel("the number of sales")
plt.ylabel('value of cryptopunks')
plt.show()
# Out:
# RMSE by hand: [0.90322237]

# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# ## Rarity Score 1

# %%
X_train = pd.DataFrame(df_R_train,columns=['Rarity_Score_1_rarest','gas_eth_price','eth_usd_price'])
y_train = pd.DataFrame(df_R_train['Log_price'])
X_test = pd.DataFrame(df_R_test,columns=['Rarity_Score_1_rarest','gas_eth_price','eth_usd_price'])
y_test = pd.DataFrame(df_R_test['Log_price'])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

mdl = RandomForestRegressor().fit(X_train, y_train)
r2 = r2_score(y_test, mdl.predict(X_test))
print(f'R2 Score: {r2}')
# Out:
# <ipython-input-59-0ebc187a0d89>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   mdl = RandomForestRegressor().fit(X_train, y_train)
# R2 Score: 0.8121245652299353

# %% [markdown]
# ## Rarity Score 2

# %%
X_train = pd.DataFrame(df_R_train,columns=['Rarity_Score_2_Average','gas_eth_price','eth_usd_price'])
y_train = pd.DataFrame(df_R_train['Log_price'])
X_test = pd.DataFrame(df_R_test,columns=['Rarity_Score_2_Average','gas_eth_price','eth_usd_price'])
y_test = pd.DataFrame(df_R_test['Log_price'])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

mdl = RandomForestRegressor().fit(X_train, y_train)
r2 = r2_score(y_test, mdl.predict(X_test))
print(f'R2 Score: {r2}')
# Out:
# <ipython-input-61-0ebc187a0d89>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   mdl = RandomForestRegressor().fit(X_train, y_train)
# R2 Score: 0.8115307407898518

# %% [markdown]
# ## Rarity Score 3

# %%
X_train = pd.DataFrame(df_R_train,columns=['Rarity_Score_3_multiple','gas_eth_price','eth_usd_price'])
y_train = pd.DataFrame(df_R_train['Log_price'])
X_test = pd.DataFrame(df_R_test,columns=['Rarity_Score_3_multiple','gas_eth_price','eth_usd_price'])
y_test = pd.DataFrame(df_R_test['Log_price'])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

mdl = RandomForestRegressor().fit(X_train, y_train)
r2 = r2_score(y_test, mdl.predict(X_test))
print(f'R2 Score: {r2}')
# Out:
# <ipython-input-63-0ebc187a0d89>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   mdl = RandomForestRegressor().fit(X_train, y_train)
# R2 Score: 0.7408687991461654

# %% [markdown]
# # Random Forest without Rarity

# %%
X_train = pd.DataFrame(df_R_train,columns=['gas_eth_price','eth_usd_price'])
y_train = pd.DataFrame(df_R_train['Log_price'])
X_test = pd.DataFrame(df_R_test,columns=['gas_eth_price','eth_usd_price'])
y_test = pd.DataFrame(df_R_test['Log_price'])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

mdl = RandomForestRegressor().fit(X_train, y_train)
r2 = r2_score(y_test, mdl.predict(X_test))
print(f'R2 Score: {r2}')
# Out:
# <ipython-input-65-0ebc187a0d89>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   mdl = RandomForestRegressor().fit(X_train, y_train)
# R2 Score: 0.8066618524217302

# %% [markdown]
# # Auto-ML

# %% [markdown]
# ## Import Packages

# %%
# !pip install autogluon
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autogluon
#   Downloading autogluon-0.7.0-py3-none-any.whl (9.7 kB)
# Collecting autogluon.core[all]==0.7.0
#   Downloading autogluon.core-0.7.0-py3-none-any.whl (218 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.3/218.3 KB 5.6 MB/s eta 0:00:00
# Collecting autogluon.tabular[all]==0.7.0
#   Downloading autogluon.tabular-0.7.0-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.2/292.2 KB 16.4 MB/s eta 0:00:00
# Collecting autogluon.multimodal==0.7.0
#   Downloading autogluon.multimodal-0.7.0-py3-none-any.whl (331 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 KB 28.9 MB/s eta 0:00:00
# Collecting autogluon.features==0.7.0
#   Downloading autogluon.features-0.7.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 KB 6.7 MB/s eta 0:00:00
# Collecting autogluon.timeseries[all]==0.7.0
#   Downloading autogluon.timeseries-0.7.0-py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.7/108.7 KB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.7.0->autogluon) (3.7.1)
# Requirement already satisfied: pandas<1.6,>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.7.0->autogluon) (1.4.4)
# Requirement already satisfied: tqdm<5,>=4.38 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.7.0->autogluon) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.7.0->autogluon) (2.27.1)
# Requirement already satisfied: scikit-learn<1.3,>=1.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.7.0->autogluon) (1.2.2)
# Collecting autogluon.common==0.7.0
#   Downloading autogluon.common-0.7.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 KB 3.4 MB/s eta 0:00:00
# Collecting networkx<3.0,>=2.3
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy<1.12,>=1.5.4 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.7.0->autogluon) (1.10.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.7.0->autogluon) (1.22.4)
# Collecting boto3<2,>=1.10
#   Downloading boto3-1.26.108-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 KB 14.4 MB/s eta 0:00:00
# Collecting ray<2.3,>=2.2
#   Downloading ray-2.2.0-cp39-cp39-manylinux2014_x86_64.whl (57.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 MB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /usr/local/lib/python3.9/dist-packages (from autogluon.core[all]==0.7.0->autogluon) (0.2.7)
# Collecting timm<0.7.0,>=0.6.12
#   Downloading timm-0.6.13-py3-none-any.whl (549 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 33.5 MB/s eta 0:00:00
# Collecting transformers<4.27.0,>=4.23.0
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 64.9 MB/s eta 0:00:00
# Collecting seqeval<1.3.0,>=1.2.2
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jsonschema<4.18,>=4.14
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 KB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.7.0->autogluon) (1.3)
# Collecting pytorch-lightning<1.10.0,>=1.9.0
#   Downloading pytorch_lightning-1.9.4-py3-none-any.whl (827 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 KB 45.7 MB/s eta 0:00:00
# Collecting openmim<0.4.0,>0.1.5
#   Downloading openmim-0.3.7-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 KB 5.5 MB/s eta 0:00:00
# Collecting torchmetrics<0.9.0,>=0.8.0
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 KB 32.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard<3,>=2.9 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.7.0->autogluon) (2.12.1)
# Collecting accelerate<0.17,>=0.9
#   Downloading accelerate-0.16.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 19.3 MB/s eta 0:00:00
# Collecting fairscale<0.4.14,>=0.4.5
#   Downloading fairscale-0.4.13.tar.gz (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 KB 9.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Pillow<9.6,>=9.3
#   Downloading Pillow-9.5.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 87.5 MB/s eta 0:00:00
# Collecting nlpaug<1.2.0,>=1.1.10
#   Downloading nlpaug-1.1.11-py3-none-any.whl (410 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 KB 35.0 MB/s eta 0:00:00
# Collecting nptyping<2.5.0,>=1.4.4
#   Downloading nptyping-2.4.1-py3-none-any.whl (36 kB)
# Collecting sentencepiece<0.2.0,>=0.1.95
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.7 MB/s eta 0:00:00
# Collecting omegaconf<2.3.0,>=2.1.1
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 KB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.7.0->autogluon) (3.8.1)
# Collecting pytesseract<0.3.11,>=0.3.9
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.7.0->autogluon) (0.7.1)
# Collecting torch<1.14,>=1.9
#   Downloading torch-1.13.1-cp39-cp39-manylinux1_x86_64.whl (887.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.7.0->autogluon) (3.1.2)
# Collecting pytorch-metric-learning<2.0,>=1.3.0
#   Downloading pytorch_metric_learning-1.7.3-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 11.0 MB/s eta 0:00:00
# Collecting evaluate<0.4.0,>=0.2.2
#   Downloading evaluate-0.3.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 KB 7.7 MB/s eta 0:00:00
# Collecting torchvision<0.15.0
#   Downloading torchvision-0.14.1-cp39-cp39-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 42.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image<0.20.0,>=0.19.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.multimodal==0.7.0->autogluon) (0.19.3)
# Collecting catboost<1.2,>=1.0
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: lightgbm<3.4,>=3.3 in /usr/local/lib/python3.9/dist-packages (from autogluon.tabular[all]==0.7.0->autogluon) (3.3.5)
# Requirement already satisfied: xgboost<1.8,>=1.6 in /usr/local/lib/python3.9/dist-packages (from autogluon.tabular[all]==0.7.0->autogluon) (1.7.5)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.tabular[all]==0.7.0->autogluon) (2.7.12)
# Collecting ujson<6,>=5
#   Downloading ujson-5.7.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 KB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels<0.14,>=0.13.0 in /usr/local/lib/python3.9/dist-packages (from autogluon.timeseries[all]==0.7.0->autogluon) (0.13.5)
# Requirement already satisfied: joblib<2,>=1.1 in /usr/local/lib/python3.9/dist-packages (from autogluon.timeseries[all]==0.7.0->autogluon) (1.1.1)
# Collecting gluonts<0.13,>=0.12.0
#   Downloading gluonts-0.12.6-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.9 MB/s eta 0:00:00
# Collecting statsforecast<1.5,>=1.4.0
#   Downloading statsforecast-1.4.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 KB 10.5 MB/s eta 0:00:00
# Collecting pmdarima<1.9,>=1.8.2
#   Downloading pmdarima-1.8.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 71.6 MB/s eta 0:00:00
# Collecting tbats<2,>=1.1
#   Downloading tbats-1.1.2-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 4.5 MB/s eta 0:00:00
# Collecting sktime<0.16,>=0.14
#   Downloading sktime-0.15.1-py3-none-any.whl (16.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 77.2 MB/s eta 0:00:00
# Requirement already satisfied: psutil<6,>=5.7.3 in /usr/local/lib/python3.9/dist-packages (from autogluon.common==0.7.0->autogluon.core[all]==0.7.0->autogluon) (5.9.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from autogluon.common==0.7.0->autogluon.core[all]==0.7.0->autogluon) (67.6.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from accelerate<0.17,>=0.9->autogluon.multimodal==0.7.0->autogluon) (23.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from accelerate<0.17,>=0.9->autogluon.multimodal==0.7.0->autogluon) (6.0)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.30.0,>=1.29.108
#   Downloading botocore-1.29.108-py3-none-any.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 99.9 MB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost<1.2,>=1.0->autogluon.tabular[all]==0.7.0->autogluon) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost<1.2,>=1.0->autogluon.tabular[all]==0.7.0->autogluon) (1.16.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost<1.2,>=1.0->autogluon.tabular[all]==0.7.0->autogluon) (0.20.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 21.9 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.7.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 18.1 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 12.2 MB/s eta 0:00:00
# Collecting datasets>=2.0.0
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 KB 39.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.9/dist-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal==0.7.0->autogluon) (2023.3.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (0.0.7)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.9/dist-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (1.0.3)
# Requirement already satisfied: pip in /usr/local/lib/python3.9/dist-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (22.0.4)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /usr/local/lib/python3.9/dist-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (1.5.29)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.9/dist-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (3.5.1)
# Requirement already satisfied: toolz~=0.10 in /usr/local/lib/python3.9/dist-packages (from gluonts<0.13,>=0.12.0->autogluon.timeseries[all]==0.7.0->autogluon) (0.12.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.9/dist-packages (from gluonts<0.13,>=0.12.0->autogluon.timeseries[all]==0.7.0->autogluon) (4.5.0)
# Requirement already satisfied: pydantic~=1.7 in /usr/local/lib/python3.9/dist-packages (from gluonts<0.13,>=0.12.0->autogluon.timeseries[all]==0.7.0->autogluon) (1.10.7)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==0.7.0->autogluon) (0.18.3)
# Requirement already satisfied: py4j in /usr/local/lib/python3.9/dist-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==0.7.0->autogluon) (0.10.9.7)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==0.7.0->autogluon) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==0.7.0->autogluon) (2.1.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema<4.18,>=4.14->autogluon.multimodal==0.7.0->autogluon) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema<4.18,>=4.14->autogluon.multimodal==0.7.0->autogluon) (22.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm<3.4,>=3.3->autogluon.tabular[all]==0.7.0->autogluon) (0.40.0)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==0.7.0->autogluon) (4.6.6)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==0.7.0->autogluon) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==0.7.0->autogluon) (8.1.3)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from openmim<0.4.0,>0.1.5->autogluon.multimodal==0.7.0->autogluon) (0.8.10)
# Collecting model-index
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from openmim<0.4.0,>0.1.5->autogluon.multimodal==0.7.0->autogluon) (13.3.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<1.6,>=1.4.1->autogluon.core[all]==0.7.0->autogluon) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas<1.6,>=1.4.1->autogluon.core[all]==0.7.0->autogluon) (2.8.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from pmdarima<1.9,>=1.8.2->autogluon.timeseries[all]==0.7.0->autogluon) (1.26.15)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima<1.9,>=1.8.2->autogluon.timeseries[all]==0.7.0->autogluon) (0.29.34)
# Collecting lightning-utilities>=0.6.0.post0
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.9/dist-packages (from ray<2.3,>=2.2->autogluon.core[all]==0.7.0->autogluon) (1.53.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ray<2.3,>=2.2->autogluon.core[all]==0.7.0->autogluon) (1.0.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from ray<2.3,>=2.2->autogluon.core[all]==0.7.0->autogluon) (3.10.7)
# Collecting aiosignal
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 93.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.9/dist-packages (from ray<2.3,>=2.2->autogluon.core[all]==0.7.0->autogluon) (3.20.3)
# Collecting frozenlist
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 16.8 MB/s eta 0:00:00
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->autogluon.core[all]==0.7.0->autogluon) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->autogluon.core[all]==0.7.0->autogluon) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->autogluon.core[all]==0.7.0->autogluon) (2.0.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.7.0->autogluon) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.7.0->autogluon) (2023.3.21)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.7.0->autogluon) (2.25.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<1.3,>=1.0->autogluon.core[all]==0.7.0->autogluon) (3.1.0)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numba>=0.55 in /usr/local/lib/python3.9/dist-packages (from sktime<0.16,>=0.14->autogluon.timeseries[all]==0.7.0->autogluon) (0.56.4)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels<0.14,>=0.13.0->autogluon.timeseries[all]==0.7.0->autogluon) (0.5.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (2.17.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (1.4.0)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 54.6 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.5 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 KB 53.0 MB/s eta 0:00:00
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.8 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.7.0->autogluon) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.7.0->autogluon) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.7.0->autogluon) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.7.0->autogluon) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.7.0->autogluon) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->autogluon.core[all]==0.7.0->autogluon) (3.0.9)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate<0.4.0,>=0.2.2->autogluon.multimodal==0.7.0->autogluon) (9.0.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.4 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.13->sktime<0.16,>=0.14->autogluon.timeseries[all]==0.7.0->autogluon) (1.14.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==0.7.0->autogluon) (4.11.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->autogluon.core[all]==0.7.0->autogluon) (3.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (6.1.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.55->sktime<0.16,>=0.14->autogluon.timeseries[all]==0.7.0->autogluon) (0.39.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (1.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (3.0.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (6.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (1.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (1.1.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (3.0.8)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (8.1.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (2.0.7)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 37.0 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.9/dist-packages (from virtualenv>=20.0.24->ray<2.3,>=2.2->autogluon.core[all]==0.7.0->autogluon) (3.2.0)
# Collecting ordered-set
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost<1.2,>=1.0->autogluon.tabular[all]==0.7.0->autogluon) (8.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->openmim<0.4.0,>0.1.5->autogluon.multimodal==0.7.0->autogluon) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->openmim<0.4.0,>0.1.5->autogluon.multimodal==0.7.0->autogluon) (2.14.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 18.6 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->openmim<0.4.0,>0.1.5->autogluon.multimodal==0.7.0->autogluon) (0.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<3,>=2.9->autogluon.multimodal==0.7.0->autogluon) (3.2.2)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.7.0->autogluon) (0.7.9)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==0.7.0->autogluon) (2.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests->autogluon.core[all]==0.7.0->autogluon) (1.7.1)
# Building wheels for collected packages: fairscale, antlr4-python3-runtime, seqeval
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.13-py3-none-any.whl size=332130 sha256=cb0530d8baaeab3bc66769a47d2378c8ebe1883e20c926c53b85f0034b570811
#   Stored in directory: /root/.cache/pip/wheels/10/ea/7f/8f35af83599829bb4790bdc16949dd99aeeb62e9a1faf47d47
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=26621ea42a54f67dedf896dd30b3259c922f52a9441d37cd210d51c6795ef10a
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=9e4f7bbdfbe898658ac0b1b4453816fbb7465d69957759f5e266ab0ef258891d
#   Stored in directory: /root/.cache/pip/wheels/e2/a5/92/2c80d1928733611c2747a9820e1324a6835524d9411510c142
# Successfully built fairscale antlr4-python3-runtime seqeval
# Installing collected packages: tokenizers, sentencepiece, distlib, antlr4-python3-runtime, xxhash, virtualenv, ujson, tensorboardX, pyDeprecate, Pillow, ordered-set, omegaconf, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nptyping, networkx, multidict, lightning-utilities, jsonschema, jmespath, frozenlist, dill, deprecated, colorama, async-timeout, yarl, responses, pytesseract, nvidia-cudnn-cu11, multiprocess, huggingface-hub, botocore, aiosignal, transformers, torch, seqeval, s3transfer, ray, model-index, gluonts, catboost, aiohttp, torchvision, torchmetrics, statsforecast, sktime, pytorch-metric-learning, pmdarima, openmim, nlpaug, fairscale, boto3, accelerate, timm, tbats, pytorch-lightning, datasets, autogluon.common, evaluate, autogluon.features, autogluon.core, autogluon.tabular, autogluon.multimodal, autogluon.timeseries, autogluon
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.0
#     Uninstalling networkx-3.0:
#       Successfully uninstalled networkx-3.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed Pillow-9.5.0 accelerate-0.16.0 aiohttp-3.8.4 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 autogluon-0.7.0 autogluon.common-0.7.0 autogluon.core-0.7.0 autogluon.features-0.7.0 autogluon.multimodal-0.7.0 autogluon.tabular-0.7.0 autogluon.timeseries-0.7.0 boto3-1.26.108 botocore-1.29.108 catboost-1.1.1 colorama-0.4.6 datasets-2.11.0 deprecated-1.2.13 dill-0.3.6 distlib-0.3.6 evaluate-0.3.0 fairscale-0.4.13 frozenlist-1.3.3 gluonts-0.12.6 huggingface-hub-0.13.4 jmespath-1.0.1 jsonschema-4.17.3 lightning-utilities-0.8.0 model-index-0.1.11 multidict-6.0.4 multiprocess-0.70.14 networkx-2.8.8 nlpaug-1.1.11 nptyping-2.4.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 omegaconf-2.2.3 openmim-0.3.7 ordered-set-4.1.0 pmdarima-1.8.5 pyDeprecate-0.3.2 pytesseract-0.3.10 pytorch-lightning-1.9.4 pytorch-metric-learning-1.7.3 ray-2.2.0 responses-0.18.0 s3transfer-0.6.0 sentencepiece-0.1.97 seqeval-1.2.2 sktime-0.15.1 statsforecast-1.4.0 tbats-1.1.2 tensorboardX-2.6 timm-0.6.13 tokenizers-0.13.3 torch-1.13.1 torchmetrics-0.8.2 torchvision-0.14.1 transformers-4.26.1 ujson-5.7.0 virtualenv-20.21.0 xxhash-3.2.0 yarl-1.8.2

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %% [markdown]
# ## Rarity Score 1

# %%
X_train = pd.DataFrame(df_R_train,columns=['Rarity_Score_1_rarest','gas_eth_price','eth_usd_price'])
y_train = pd.DataFrame(df_R_train['Log_price'])
X_test = pd.DataFrame(df_R_test,columns=['Rarity_Score_1_rarest','gas_eth_price','eth_usd_price'])
y_test = pd.DataFrame(df_R_test['Log_price'])

# %%
train_df = pd.DataFrame(X_train)
train_df['target'] = y_train.values

test_df = pd.DataFrame(X_test)
test_df['target'] = y_test.values

train_data = TabularDataset(train_df)
test_data = TabularDataset(test_df)

predictor = TabularPredictor(
    path='AutogluonModels/regression/',
    label='target'
).fit(train_data)


predictor = TabularPredictor.load("AutogluonModels/regression/")
# reference: https://auto.gluon.ai/stable/cheatsheet.html
# https://auto.gluon.ai/0.3.1/api/autogluon.tabular.models.html
predictor.leaderboard(silent=True, data=test_data, extra_metrics=["r2"])
# Out:
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/regression/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.16
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Dec 10 16:00:40 UTC 2022
# Train Data Rows:    6155
# Train Data Columns: 3
# Label Column: target
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (16.14569136254912, -35.790050472354636, 7.96168, 3.54989)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11714.66 MB
# 	Train Data (Original)  Memory Usage: 0.15 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 3 | ['Rarity_Score_1_rarest', 'gas_eth_price', 'eth_usd_price']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 3 | ['Rarity_Score_1_rarest', 'gas_eth_price', 'eth_usd_price']
# 	0.1s = Fit runtime
# 	3 features in original data used to generate 3 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 5539, Val Rows: 616
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-1.8595	 = Validation score   (-root_mean_squared_error)
# 	1.71s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-1.8539	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 1.82727
# [2000]	valid_set's rmse: 1.80456
# [3000]	valid_set's rmse: 1.79608
# 	-1.7951	 = Validation score   (-root_mean_squared_error)
# 	3.88s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBM ...
# 	-1.7325	 = Validation score   (-root_mean_squared_error)
# 	0.9s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-1.7216	 = Validation score   (-root_mean_squared_error)
# 	8.82s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-1.7245	 = Validation score   (-root_mean_squared_error)
# 	165.72s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-1.7273	 = Validation score   (-root_mean_squared_error)
# 	3.19s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-1.9023	 = Validation score   (-root_mean_squared_error)
# 	8.1s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-1.7115	 = Validation score   (-root_mean_squared_error)
# 	1.19s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-1.8676	 = Validation score   (-root_mean_squared_error)
# 	36.9s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-1.7493	 = Validation score   (-root_mean_squared_error)
# 	1.54s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-1.7021	 = Validation score   (-root_mean_squared_error)
# 	0.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 235.14s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/regression/")
#                   model  score_test        r2  score_val  pred_time_test  \
# 0         ExtraTreesMSE   -0.637974  0.826998  -1.727330        0.324176
# 1   WeightedEnsemble_L2   -0.642059  0.824775  -1.702102        0.630090
# 2               XGBoost   -0.654160  0.818108  -1.711476        0.153866
# 3       RandomForestMSE   -0.656456  0.816829  -1.721619        0.346807
# 4         LightGBMLarge   -0.668469  0.810063  -1.749273        0.054740
# 5              LightGBM   -0.687814  0.798911  -1.732535        0.076660
# 6              CatBoost   -0.772386  0.746420  -1.724542        0.048336
# 7            LightGBMXT   -0.773365  0.745777  -1.795099        0.997748
# 8        KNeighborsDist   -0.831018  0.706460  -1.853875        0.015451
# 9       NeuralNetFastAI   -0.838923  0.700848  -1.902330        0.069300
# 10       KNeighborsUnif   -0.838942  0.700835  -1.859454        0.015551
# 11       NeuralNetTorch   -0.935506  0.628003  -1.867624        0.017534
#
#     pred_time_val    fit_time  pred_time_test_marginal  \
# 0        0.176635    3.188946                 0.324176
# 1        0.377454  177.002941                 0.004421
# 2        0.033684    1.193667                 0.153866
# 3        0.306990    8.815629                 0.346807
# 4        0.011069    1.540877                 0.054740
# 5        0.018989    0.897005                 0.076660
# 6        0.017193  165.718643                 0.048336
# 7        0.180255    3.878000                 0.997748
# 8        0.006246    0.011130                 0.015451
# 9        0.016426    8.098255                 0.069300
# 10       0.011394    1.705612                 0.015551
# 11       0.010670   36.904104                 0.017534
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.176635           3.188946            1       True
# 1                 0.000597           0.377997            2       True
# 2                 0.033684           1.193667            1       True
# 3                 0.306990           8.815629            1       True
# 4                 0.011069           1.540877            1       True
# 5                 0.018989           0.897005            1       True
# 6                 0.017193         165.718643            1       True
# 7                 0.180255           3.878000            1       True
# 8                 0.006246           0.011130            1       True
# 9                 0.016426           8.098255            1       True
# 10                0.011394           1.705612            1       True
# 11                0.010670          36.904104            1       True
#
#     fit_order
# 0           7
# 1          12
# 2           9
# 3           5
# 4          11
# 5           4
# 6           6
# 7           3
# 8           2
# 9           8
# 10          1
# 11         10

# %% [markdown]
# ## Rarity Score 2

# %%
X_train = pd.DataFrame(df_R_train,columns=['Rarity_Score_2_Average','gas_eth_price','eth_usd_price'])
y_train = pd.DataFrame(df_R_train['Log_price'])
X_test = pd.DataFrame(df_R_test,columns=['Rarity_Score_2_Average','gas_eth_price','eth_usd_price'])
y_test = pd.DataFrame(df_R_test['Log_price'])

# %%
train_df = pd.DataFrame(X_train)
train_df['target'] = y_train.values

test_df = pd.DataFrame(X_test)
test_df['target'] = y_test.values

train_data = TabularDataset(train_df)
test_data = TabularDataset(test_df)

predictor = TabularPredictor(
    path='AutogluonModels/regression/',
    label='target'
).fit(train_data)


predictor = TabularPredictor.load("AutogluonModels/regression/")
# reference: https://auto.gluon.ai/stable/cheatsheet.html
# https://auto.gluon.ai/0.3.1/api/autogluon.tabular.models.html
predictor.leaderboard(silent=True, data=test_data, extra_metrics=["r2"])
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/regression/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/regression/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.16
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Dec 10 16:00:40 UTC 2022
# Train Data Rows:    6155
# Train Data Columns: 3
# Label Column: target
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (16.14569136254912, -35.790050472354636, 7.96168, 3.54989)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11650.84 MB
# 	Train Data (Original)  Memory Usage: 0.15 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 3 | ['Rarity_Score_2_Average', 'gas_eth_price', 'eth_usd_price']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 3 | ['Rarity_Score_2_Average', 'gas_eth_price', 'eth_usd_price']
# 	0.1s = Fit runtime
# 	3 features in original data used to generate 3 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 5539, Val Rows: 616
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-1.8179	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-1.7973	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 1.85076
# [2000]	valid_set's rmse: 1.82506
# [3000]	valid_set's rmse: 1.82442
# 	-1.8232	 = Validation score   (-root_mean_squared_error)
# 	2.56s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBM ...
# 	-1.7468	 = Validation score   (-root_mean_squared_error)
# 	0.59s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-1.7447	 = Validation score   (-root_mean_squared_error)
# 	4.53s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-1.7717	 = Validation score   (-root_mean_squared_error)
# 	10.88s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-1.736	 = Validation score   (-root_mean_squared_error)
# 	4.9s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-1.8909	 = Validation score   (-root_mean_squared_error)
# 	22.06s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-1.8498	 = Validation score   (-root_mean_squared_error)
# 	0.9s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-1.851	 = Validation score   (-root_mean_squared_error)
# 	43.22s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-1.7484	 = Validation score   (-root_mean_squared_error)
# 	1.26s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-1.7318	 = Validation score   (-root_mean_squared_error)
# 	0.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 95.84s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/regression/")
#                   model  score_test        r2  score_val  pred_time_test  \
# 0         ExtraTreesMSE   -0.631141  0.830683  -1.735990        0.287876
# 1   WeightedEnsemble_L2   -0.633957  0.829169  -1.731813        1.062336
# 2       RandomForestMSE   -0.642063  0.824773  -1.744726        0.672899
# 3         LightGBMLarge   -0.685198  0.800438  -1.748438        0.041390
# 4               XGBoost   -0.685862  0.800050  -1.849805        0.020362
# 5              LightGBM   -0.691621  0.796678  -1.746785        0.055497
# 6              CatBoost   -0.695759  0.794238  -1.771749        0.010548
# 7            LightGBMXT   -0.764984  0.751257  -1.823227        1.005854
# 8        KNeighborsDist   -0.811448  0.720122  -1.797286        0.015281
# 9        KNeighborsUnif   -0.828623  0.708150  -1.817873        0.015676
# 10      NeuralNetFastAI   -0.832966  0.705082  -1.890857        0.072491
# 11       NeuralNetTorch   -0.936243  0.627416  -1.850979        0.024734
#
#     pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0        0.362599   4.899493                 0.287876                0.362599
# 1        0.566131  11.651264                 0.004674                0.000646
# 2        0.181728   4.526593                 0.672899                0.181728
# 3        0.008835   1.257297                 0.041390                0.008835
# 4        0.008104   0.898340                 0.020362                0.008104
# 5        0.012323   0.591969                 0.055497                0.012323
# 6        0.004334  10.883078                 0.010548                0.004334
# 7        0.181458   2.561249                 1.005854                0.181458
# 8        0.007047   0.010936                 0.015281                0.007047
# 9        0.006728   0.014543                 0.015676                0.006728
# 10       0.048851  22.064468                 0.072491                0.048851
# 11       0.011132  43.221640                 0.024734                0.011132
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            4.899493            1       True          7
# 1            0.375913            2       True         12
# 2            4.526593            1       True          5
# 3            1.257297            1       True         11
# 4            0.898340            1       True          9
# 5            0.591969            1       True          4
# 6           10.883078            1       True          6
# 7            2.561249            1       True          3
# 8            0.010936            1       True          2
# 9            0.014543            1       True          1
# 10          22.064468            1       True          8
# 11          43.221640            1       True         10

# %% [markdown]
# ## Rarity Score 3

# %%
X_train = pd.DataFrame(df_R_train,columns=['Rarity_Score_3_multiple','gas_eth_price','eth_usd_price'])
y_train = pd.DataFrame(df_R_train['Log_price'])
X_test = pd.DataFrame(df_R_test,columns=['Rarity_Score_3_multiple','gas_eth_price','eth_usd_price'])
y_test = pd.DataFrame(df_R_test['Log_price'])

# %%
train_df = pd.DataFrame(X_train)
train_df['target'] = y_train.values

test_df = pd.DataFrame(X_test)
test_df['target'] = y_test.values

train_data = TabularDataset(train_df)
test_data = TabularDataset(test_df)

predictor = TabularPredictor(
    path='AutogluonModels/regression/',
    label='target'
).fit(train_data)


predictor = TabularPredictor.load("AutogluonModels/regression/")
# reference: https://auto.gluon.ai/stable/cheatsheet.html
# https://auto.gluon.ai/0.3.1/api/autogluon.tabular.models.html
predictor.leaderboard(silent=True, data=test_data, extra_metrics=["r2"])
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/regression/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/regression/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.16
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Dec 10 16:00:40 UTC 2022
# Train Data Rows:    6155
# Train Data Columns: 3
# Label Column: target
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (16.14569136254912, -35.790050472354636, 7.96168, 3.54989)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11541.49 MB
# 	Train Data (Original)  Memory Usage: 0.15 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 3 | ['Rarity_Score_3_multiple', 'gas_eth_price', 'eth_usd_price']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 3 | ['Rarity_Score_3_multiple', 'gas_eth_price', 'eth_usd_price']
# 	0.1s = Fit runtime
# 	3 features in original data used to generate 3 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 5539, Val Rows: 616
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-1.8603	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-1.8512	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 1.86012
# [2000]	valid_set's rmse: 1.84223
# [3000]	valid_set's rmse: 1.83482
# [4000]	valid_set's rmse: 1.83507
# 	-1.8327	 = Validation score   (-root_mean_squared_error)
# 	4.35s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBM ...
# 	-1.7475	 = Validation score   (-root_mean_squared_error)
# 	1.08s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-1.7352	 = Validation score   (-root_mean_squared_error)
# 	6.48s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-1.7825	 = Validation score   (-root_mean_squared_error)
# 	2.93s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-1.7427	 = Validation score   (-root_mean_squared_error)
# 	1.73s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-1.9122	 = Validation score   (-root_mean_squared_error)
# 	8.38s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-1.7672	 = Validation score   (-root_mean_squared_error)
# 	0.88s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-1.8973	 = Validation score   (-root_mean_squared_error)
# 	30.16s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-1.7509	 = Validation score   (-root_mean_squared_error)
# 	1.33s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-1.7319	 = Validation score   (-root_mean_squared_error)
# 	0.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 60.49s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/regression/")
#                   model  score_test        r2  score_val  pred_time_test  \
# 0         ExtraTreesMSE   -0.696919  0.793552  -1.742667        0.274338
# 1   WeightedEnsemble_L2   -0.710466  0.785447  -1.731863        0.778376
# 2         LightGBMLarge   -0.713885  0.783378  -1.750855        0.069852
# 3              LightGBM   -0.727576  0.774989  -1.747466        0.107104
# 4       RandomForestMSE   -0.736033  0.769728  -1.735161        0.392941
# 5              CatBoost   -0.754344  0.758128  -1.782550        0.011354
# 6               XGBoost   -0.774475  0.745046  -1.767177        0.033716
# 7            LightGBMXT   -0.803011  0.725912  -1.832748        1.247235
# 8       NeuralNetFastAI   -0.849512  0.693249  -1.912238        0.064071
# 9        KNeighborsUnif   -0.868350  0.679494  -1.860262        0.014966
# 10       NeuralNetTorch   -0.870005  0.678271  -1.897250        0.017506
# 11       KNeighborsDist   -0.879054  0.671544  -1.851154        0.015431
#
#     pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0        0.103212   1.726440                 0.274338                0.103212
# 1        0.242988   9.669417                 0.003994                0.000597
# 2        0.014269   1.332948                 0.069852                0.014269
# 3        0.025780   1.075071                 0.107104                0.025780
# 4        0.113399   6.479431                 0.392941                0.113399
# 5        0.004015   2.934017                 0.011354                0.004015
# 6        0.011772   0.884360                 0.033716                0.011772
# 7        0.299268   4.352580                 1.247235                0.299268
# 8        0.024302   8.384379                 0.064071                0.024302
# 9        0.006782   0.014392                 0.014966                0.006782
# 10       0.006999  30.155873                 0.017506                0.006999
# 11       0.007350   0.013758                 0.015431                0.007350
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            1.726440            1       True          7
# 1            0.388474            2       True         12
# 2            1.332948            1       True         11
# 3            1.075071            1       True          4
# 4            6.479431            1       True          5
# 5            2.934017            1       True          6
# 6            0.884360            1       True          9
# 7            4.352580            1       True          3
# 8            8.384379            1       True          8
# 9            0.014392            1       True          1
# 10          30.155873            1       True         10
# 11           0.013758            1       True          2
